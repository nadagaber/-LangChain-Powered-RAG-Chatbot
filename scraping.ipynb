# %%
import requests
from bs4 import BeautifulSoup
import os
from urllib.parse import urljoin, urlparse

base_url = "https://python.langchain.com"
sections = [
    "/docs/get_started/introduction",
    "/docs/tutorials",
    "/docs/how_to",
    "/docs/concepts"
]

visited_urls = set()
output_dir = "langchain_selected_docs"
os.makedirs(output_dir, exist_ok=True)

def fetch_and_save(url):
    """Fetch page, extract text from <main>, and save it to a .txt file."""
    try:
        print(f"Fetching: {url}")
        res = requests.get(url)
        res.raise_for_status()
        soup = BeautifulSoup(res.text, "html.parser")
        main = soup.find("main")
        if main:
            text = main.get_text(separator="\n").strip()
            parsed = urlparse(url)
            filename = parsed.path.strip("/").replace("/", "_") or "index"
            with open(os.path.join(output_dir, f"{filename}.txt"), "w", encoding="utf-8") as f:
                f.write(text)
        return soup
    except Exception as e:
        print(f"Error fetching {url}: {e}")
        return None

def extract_internal_links(soup, section_root):
    """Extract only direct internal child links within the section."""
    root_parts = section_root.strip("/").split("/")
    links = set()
    for a in soup.find_all("a", href=True):
        href = a["href"].split("#")[0]
        if not href.startswith("/"):
            continue
        if href.startswith(section_root):
            parts = href.strip("/").split("/")
            if len(parts) == len(root_parts) + 1:
                full_url = urljoin(base_url, href)
                links.add(full_url)
    return links


for section in sections:
    section_url = urljoin(base_url, section)
    if section_url in visited_urls:
        continue
    visited_urls.add(section_url)

    soup = fetch_and_save(section_url)
    if soup:
        child_links = extract_internal_links(soup, section)
        for child_url in child_links:
            if child_url not in visited_urls:
                visited_urls.add(child_url)
                fetch_and_save(child_url)
# Out:
# Fetching: https://python.langchain.com/docs/get_started/introduction
# Fetching: https://python.langchain.com/docs/tutorials
# Fetching: https://python.langchain.com/docs/tutorials/agents/
# Fetching: https://python.langchain.com/docs/tutorials/rag/
# Fetching: https://python.langchain.com/docs/tutorials/classification/
# Fetching: https://python.langchain.com/docs/tutorials/chatbot/
# Fetching: https://python.langchain.com/docs/tutorials/retrievers/
# Fetching: https://python.langchain.com/docs/tutorials/qa_chat_history/
# Fetching: https://python.langchain.com/docs/tutorials/summarization/
# Fetching: https://python.langchain.com/docs/tutorials/graph/
# Fetching: https://python.langchain.com/docs/tutorials/extraction/
# Fetching: https://python.langchain.com/docs/tutorials/llm_chain/
# Fetching: https://python.langchain.com/docs/tutorials/sql_qa/
# Fetching: https://python.langchain.com/docs/how_to
# Fetching: https://python.langchain.com/docs/how_to/fallbacks/
# Fetching: https://python.langchain.com/docs/how_to/routing/
# Fetching: https://python.langchain.com/docs/how_to/query_multiple_queries/
# Fetching: https://python.langchain.com/docs/how_to/example_selectors_similarity/
# Fetching: https://python.langchain.com/docs/how_to/multi_vector/
# Fetching: https://python.langchain.com/docs/how_to/configure/
# Fetching: https://python.langchain.com/docs/how_to/tool_artifacts/
# Fetching: https://python.langchain.com/docs/how_to/serialization/
# Fetching: https://python.langchain.com/docs/how_to/add_scores_retriever/
# Fetching: https://python.langchain.com/docs/how_to/few_shot_examples_chat/
# Fetching: https://python.langchain.com/docs/how_to/callbacks_custom_events/
# Fetching: https://python.langchain.com/docs/how_to/toolkits/
# Fetching: https://python.langchain.com/docs/how_to/ensemble_retriever/
# Fetching: https://python.langchain.com/docs/how_to/tools_builtin/
# Fetching: https://python.langchain.com/docs/how_to/parallel/
# Fetching: https://python.langchain.com/docs/how_to/qa_citations/
# Fetching: https://python.langchain.com/docs/how_to/structured_output/
# Fetching: https://python.langchain.com/docs/how_to/document_loader_office_file/
# Fetching: https://python.langchain.com/docs/how_to/assign/
# Fetching: https://python.langchain.com/docs/how_to/example_selectors_ngram/
# Fetching: https://python.langchain.com/docs/how_to/query_no_queries/
# Fetching: https://python.langchain.com/docs/how_to/lcel_cheatsheet/
# Fetching: https://python.langchain.com/docs/how_to/streaming_llm/
# Fetching: https://python.langchain.com/docs/how_to/sql_large_db/
# Fetching: https://python.langchain.com/docs/how_to/tools_human/
# Fetching: https://python.langchain.com/docs/how_to/chat_model_caching/
# Fetching: https://python.langchain.com/docs/how_to/few_shot_examples/
# Fetching: https://python.langchain.com/docs/how_to/parent_document_retriever/
# Fetching: https://python.langchain.com/docs/how_to/dynamic_chain/
# Fetching: https://python.langchain.com/docs/how_to/chat_token_usage_tracking/
# Fetching: https://python.langchain.com/docs/how_to/recursive_text_splitter/
# Fetching: https://python.langchain.com/docs/how_to/tools_as_openai_functions/
# Fetching: https://python.langchain.com/docs/how_to/vectorstore_retriever/
# Fetching: https://python.langchain.com/docs/how_to/document_loader_pdf/
# Fetching: https://python.langchain.com/docs/how_to/document_loader_json/
# Fetching: https://python.langchain.com/docs/how_to/output_parser_xml/
# Fetching: https://python.langchain.com/docs/how_to/streaming/
# Fetching: https://python.langchain.com/docs/how_to/time_weighted_vectorstore/
# Fetching: https://python.langchain.com/docs/how_to/functions/
# Fetching: https://python.langchain.com/docs/how_to/sql_prompting/
# Fetching: https://python.langchain.com/docs/how_to/custom_tools/
# Fetching: https://python.langchain.com/docs/how_to/callbacks_attach/
# Fetching: https://python.langchain.com/docs/how_to/contextual_compression/
# Fetching: https://python.langchain.com/docs/how_to/tools_chain/
# Fetching: https://python.langchain.com/docs/how_to/installation/
# Fetching: https://python.langchain.com/docs/how_to/llm_caching/
# Fetching: https://python.langchain.com/docs/how_to/query_multiple_retrievers/
# Fetching: https://python.langchain.com/docs/how_to/markdown_header_metadata_splitter/
# Fetching: https://python.langchain.com/docs/how_to/passthrough/
# Fetching: https://python.langchain.com/docs/how_to/qa_sources/
# Fetching: https://python.langchain.com/docs/how_to/graph_constructing/
# Fetching: https://python.langchain.com/docs/how_to/logprobs/
# Fetching: https://python.langchain.com/docs/how_to/output_parser_json/
# Fetching: https://python.langchain.com/docs/how_to/tool_choice/
# Fetching: https://python.langchain.com/docs/how_to/embed_text/
# Fetching: https://python.langchain.com/docs/how_to/chatbots_memory/
# Fetching: https://python.langchain.com/docs/how_to/runnable_runtime_secrets/
# Fetching: https://python.langchain.com/docs/how_to/local_llms/
# Fetching: https://python.langchain.com/docs/how_to/response_metadata/
# Fetching: https://python.langchain.com/docs/how_to/sql_csv/
# Fetching: https://python.langchain.com/docs/how_to/document_loader_custom/
# Fetching: https://python.langchain.com/docs/how_to/chat_model_rate_limiting/
# Fetching: https://python.langchain.com/docs/how_to/inspect/
# Fetching: https://python.langchain.com/docs/how_to/example_selectors_langsmith/
# Fetching: https://python.langchain.com/docs/how_to/tool_calling_parallel/
# Fetching: https://python.langchain.com/docs/how_to/prompts_composition/
# Fetching: https://python.langchain.com/docs/how_to/caching_embeddings/
# Fetching: https://python.langchain.com/docs/how_to/custom_llm/
# Fetching: https://python.langchain.com/docs/how_to/trim_messages/
# Fetching: https://python.langchain.com/docs/how_to/custom_chat_model/
# Fetching: https://python.langchain.com/docs/how_to/output_parser_string/
# Fetching: https://python.langchain.com/docs/how_to/query_constructing_filters/
# Fetching: https://python.langchain.com/docs/how_to/MultiQueryRetriever/
# Fetching: https://python.langchain.com/docs/how_to/chat_models_universal_init/
# Fetching: https://python.langchain.com/docs/how_to/tool_configure/
# Fetching: https://python.langchain.com/docs/how_to/graph_semantic/
# Fetching: https://python.langchain.com/docs/how_to/chatbots_tools/
# Fetching: https://python.langchain.com/docs/how_to/tools_model_specific/
# Fetching: https://python.langchain.com/docs/how_to/qa_streaming/
# Fetching: https://python.langchain.com/docs/how_to/code_splitter/
# Fetching: https://python.langchain.com/docs/how_to/example_selectors_length_based/
# Fetching: https://python.langchain.com/docs/how_to/custom_embeddings/
# Fetching: https://python.langchain.com/docs/how_to/pydantic_compatibility/
# Fetching: https://python.langchain.com/docs/how_to/function_calling/
# Fetching: https://python.langchain.com/docs/how_to/callbacks_runtime/
# Fetching: https://python.langchain.com/docs/how_to/multimodal_inputs/
# Fetching: https://python.langchain.com/docs/how_to/summarize_refine/
# Fetching: https://python.langchain.com/docs/how_to/split_by_token/
# Fetching: https://python.langchain.com/docs/how_to/sequence/
# Fetching: https://python.langchain.com/docs/how_to/llm_token_usage_tracking/
# Fetching: https://python.langchain.com/docs/how_to/callbacks_async/
# Fetching: https://python.langchain.com/docs/how_to/prompts_partial/
# Fetching: https://python.langchain.com/docs/how_to/chatbots_retrieval/
# Fetching: https://python.langchain.com/docs/how_to/filter_messages/
# Fetching: https://python.langchain.com/docs/how_to/tools_error/
# Fetching: https://python.langchain.com/docs/how_to/output_parser_fixing/
# Fetching: https://python.langchain.com/docs/how_to/multimodal_prompts/
# Fetching: https://python.langchain.com/docs/how_to/document_loader_markdown/
# Fetching: https://python.langchain.com/docs/how_to/merge_message_runs/
# Fetching: https://python.langchain.com/docs/how_to/tool_calling/
# Fetching: https://python.langchain.com/docs/how_to/tools_prompting/
# Fetching: https://python.langchain.com/docs/how_to/chat_streaming/
# Fetching: https://python.langchain.com/docs/how_to/document_loader_html/
# Fetching: https://python.langchain.com/docs/how_to/extraction_parse/
# Fetching: https://python.langchain.com/docs/how_to/example_selectors/
# Fetching: https://python.langchain.com/docs/how_to/query_few_shot/
# Fetching: https://python.langchain.com/docs/how_to/document_loader_directory/
# Fetching: https://python.langchain.com/docs/how_to/output_parser_yaml/
# Fetching: https://python.langchain.com/docs/how_to/summarize_map_reduce/
# Fetching: https://python.langchain.com/docs/how_to/custom_retriever/
# Fetching: https://python.langchain.com/docs/how_to/vectorstores/
# Fetching: https://python.langchain.com/docs/how_to/agent_executor/
# Fetching: https://python.langchain.com/docs/how_to/long_context_reorder/
# Fetching: https://python.langchain.com/docs/how_to/output_parser_retry/
# Fetching: https://python.langchain.com/docs/how_to/recursive_json_splitter/
# Fetching: https://python.langchain.com/docs/how_to/tool_stream_events/
# Fetching: https://python.langchain.com/docs/how_to/custom_callbacks/
# Fetching: https://python.langchain.com/docs/how_to/qa_per_user/
# Fetching: https://python.langchain.com/docs/how_to/semantic-chunker/
# Fetching: https://python.langchain.com/docs/how_to/output_parser_structured/
# Fetching: https://python.langchain.com/docs/how_to/query_high_cardinality/
# Fetching: https://python.langchain.com/docs/how_to/split_html/
# Fetching: https://python.langchain.com/docs/how_to/tool_runtime/
# Fetching: https://python.langchain.com/docs/how_to/binding/
# Fetching: https://python.langchain.com/docs/how_to/sql_query_checking/
# Fetching: https://python.langchain.com/docs/how_to/summarize_stuff/
# Fetching: https://python.langchain.com/docs/how_to/tools_few_shot/
# Fetching: https://python.langchain.com/docs/how_to/document_loader_csv/
# Fetching: https://python.langchain.com/docs/how_to/self_query/
# Fetching: https://python.langchain.com/docs/how_to/example_selectors_mmr/
# Fetching: https://python.langchain.com/docs/how_to/indexing/
# Fetching: https://python.langchain.com/docs/how_to/extraction_long_text/
# Fetching: https://python.langchain.com/docs/how_to/document_loader_web/
# Fetching: https://python.langchain.com/docs/how_to/migrate_agent/
# Fetching: https://python.langchain.com/docs/how_to/qa_chat_history_how_to/
# Fetching: https://python.langchain.com/docs/how_to/callbacks_constructor/
# Fetching: https://python.langchain.com/docs/how_to/hybrid/
# Fetching: https://python.langchain.com/docs/how_to/extraction_examples/
# Fetching: https://python.langchain.com/docs/how_to/tool_streaming/
# Fetching: https://python.langchain.com/docs/how_to/message_history/
# Fetching: https://python.langchain.com/docs/how_to/convert_runnable_to_tool/
# Fetching: https://python.langchain.com/docs/how_to/character_text_splitter/
# Fetching: https://python.langchain.com/docs/how_to/tool_results_pass_to_model/
# Fetching: https://python.langchain.com/docs/how_to/output_parser_custom/
# Fetching: https://python.langchain.com/docs/how_to/debugging/
# Fetching: https://python.langchain.com/docs/concepts
# Fetching: https://python.langchain.com/docs/concepts/text_llms/
# Fetching: https://python.langchain.com/docs/concepts/tracing/
# Fetching: https://python.langchain.com/docs/concepts/agents/
# Fetching: https://python.langchain.com/docs/concepts/messages/
# Fetching: https://python.langchain.com/docs/concepts/rag/
# Fetching: https://python.langchain.com/docs/concepts/structured_outputs/
# Fetching: https://python.langchain.com/docs/concepts/architecture/
# Fetching: https://python.langchain.com/docs/concepts/retrieval/
# Fetching: https://python.langchain.com/docs/concepts/vectorstores/
# Fetching: https://python.langchain.com/docs/concepts/lcel/
# Fetching: https://python.langchain.com/docs/concepts/retrievers/
# Fetching: https://python.langchain.com/docs/concepts/why_langchain/
# Fetching: https://python.langchain.com/docs/concepts/prompt_templates/
# Fetching: https://python.langchain.com/docs/concepts/chat_models/
# Fetching: https://python.langchain.com/docs/concepts/tokens/
# Fetching: https://python.langchain.com/docs/concepts/async/
# Fetching: https://python.langchain.com/docs/concepts/streaming/
# Fetching: https://python.langchain.com/docs/concepts/embedding_models/
# Fetching: https://python.langchain.com/docs/concepts/evaluation/
# Fetching: https://python.langchain.com/docs/concepts/callbacks/
# Fetching: https://python.langchain.com/docs/concepts/key_value_stores/
# Fetching: https://python.langchain.com/docs/concepts/tools/
# Fetching: https://python.langchain.com/docs/concepts/example_selectors/
# Fetching: https://python.langchain.com/docs/concepts/testing/
# Fetching: https://python.langchain.com/docs/concepts/tool_calling/
# Fetching: https://python.langchain.com/docs/concepts/runnables/
# Fetching: https://python.langchain.com/docs/concepts/multimodality/
# Fetching: https://python.langchain.com/docs/concepts/output_parsers/
# Fetching: https://python.langchain.com/docs/concepts/chat_history/
# Fetching: https://python.langchain.com/docs/concepts/document_loaders/
# Fetching: https://python.langchain.com/docs/concepts/few_shot_prompting/
# Fetching: https://python.langchain.com/docs/concepts/text_splitters/

# %%
# MERGING

input_dir = "langchain_selected_docs"
output_file = "merged_langchain_docs.txt"

with open(output_file, "w", encoding="utf-8") as outfile:
    for filename in sorted(os.listdir(input_dir)):
        if filename.endswith(".txt"):
            file_path = os.path.join(input_dir, filename)
            with open(file_path, "r", encoding="utf-8") as infile:
                outfile.write(f"\n--- {filename} ---\n\n")
                outfile.write(infile.read())
                outfile.write("\n\n")

# %%
#/docs/get_started/introduction#installation

# import requests
# from bs4 import BeautifulSoup
# from urllib.parse import urljoin

# base_url = "https://python.langchain.com"
# how_to_index_url = urljoin(base_url, "/docs/how_to")

# output_file = "langchain_how_to_qa.txt"

# def get_main_text(url):
#     """Extract text from <main> tag of a page."""
#     try:
#         res = requests.get(url)
#         res.raise_for_status()
#         soup = BeautifulSoup(res.text, "html.parser")
#         main = soup.find("main")
#         return main.get_text(separator="\n").strip() if main else ""
#     except Exception as e:
#         print(f"Error getting {url}: {e}")
#         return ""

# def extract_how_to_links():
#     """Extract 'How to:' entries and their links from the index page."""
#     res = requests.get(how_to_index_url)
#     soup = BeautifulSoup(res.text, "html.parser")
#     main = soup.find("main")

#     links = []
#     for a in main.find_all("a", href=True):
#         if a.text.strip().startswith("How to:"):
#             full_url = urljoin(base_url, a['href'].split("#")[0])
#             links.append((a.text.strip(), full_url))
#     return links

# def build_qa_dataset():
#     how_to_entries = extract_how_to_links()
#     with open(output_file, "w", encoding="utf-8") as f:
#         for title, url in how_to_entries:
#             print(f"Processing: {title}")
#             content = get_main_text(url)
#             f.write(f"{title}\n{content}\n\n")

# build_qa_dataset()
# Out:
# Processing: How to: install LangChain packages
# Processing: How to: use LangChain with different Pydantic versions
# Processing: How to: return structured data from a model
# Processing: How to: use a model to call tools
# Processing: How to: stream runnables
# Processing: How to: debug your LLM apps
# Processing: How to: do function/tool calling
# Processing: How to: get models to return structured output
# Processing: How to: cache model responses
# Processing: How to: get log probabilities
# Processing: How to: create a custom chat model class
# Processing: How to: stream a response back
# Processing: How to: track token usage
# Processing: How to: track response metadata across providers
# Processing: How to: use chat model to call tools
# Processing: How to: stream tool calls
# Processing: How to: handle rate limits
# Processing: How to: few shot prompt tool behavior
# Processing: How to: bind model-specific formatted tools
# Processing: How to: force a specific tool call
# Processing: How to: work with local models
# Processing: How to: init any model in one line
# Processing: How to: pass multimodal data directly to models
# Processing: How to: trim messages
# Processing: How to: filter messages
# Processing: How to: merge consecutive messages of the same type
# Processing: How to: use few shot examples
# Processing: How to: use few shot examples in chat models
# Processing: How to: partially format prompt templates
# Processing: How to: compose prompts together
# Processing: How to: use multimodal prompts
# Processing: How to: use example selectors
# Processing: How to: select examples by length
# Processing: How to: select examples by semantic similarity
# Processing: How to: select examples by semantic ngram overlap
# Processing: How to: select examples by maximal marginal relevance
# Processing: How to: select examples from LangSmith few-shot datasets
# Processing: How to: cache model responses
# Processing: How to: create a custom LLM class
# Processing: How to: stream a response back
# Processing: How to: track token usage
# Processing: How to: work with local models
# Processing: How to: parse text from message objects
# Processing: How to: use output parsers to parse an LLM response into structured format
# Processing: How to: parse JSON output
# Processing: How to: parse XML output
# Processing: How to: parse YAML output
# Processing: How to: retry when output parsing errors occur
# Processing: How to: try to fix errors in output parsing
# Processing: How to: write a custom output parser class
# Processing: How to: load PDF files
# Processing: How to: load web pages
# Processing: How to: load CSV data
# Processing: How to: load data from a directory
# Processing: How to: load HTML data
# Processing: How to: load JSON data
# Processing: How to: load Markdown data
# Processing: How to: load Microsoft Office data
# Processing: How to: write a custom document loader
# Processing: How to: recursively split text
# Processing: How to: split HTML
# Processing: How to: split by character
# Processing: How to: split code
# Processing: How to: split Markdown by headers
# Processing: How to: recursively split JSON
# Processing: How to: split text into semantic chunks
# Processing: How to: split by tokens
# Processing: How to: embed text data
# Processing: How to: cache embedding results
# Processing: How to: create a custom embeddings class
# Processing: How to: use a vector store to retrieve data
# Processing: How to: use a vector store to retrieve data
# Processing: How to: generate multiple queries to retrieve data for
# Processing: How to: use contextual compression to compress the data retrieved
# Processing: How to: write a custom retriever class
# Processing: How to: add similarity scores to retriever results
# Processing: How to: combine the results from multiple retrievers
# Processing: How to: reorder retrieved results to mitigate the "lost in the middle" effect
# Processing: How to: generate multiple embeddings per document
# Processing: How to: retrieve the whole document for a chunk
# Processing: How to: generate metadata filters
# Processing: How to: create a time-weighted retriever
# Processing: How to: use hybrid vector and keyword retrieval
# Processing: How to: reindex data to keep your vectorstore in-sync with the underlying data source
# Processing: How to: create tools
# Processing: How to: use built-in tools and toolkits
# Processing: How to: use chat models to call tools
# Processing: How to: pass tool outputs to chat models
# Processing: How to: pass run time values to tools
# Processing: How to: add a human-in-the-loop for tools
# Processing: How to: handle tool errors
# Processing: How to: force models to call a tool
# Processing: How to: disable parallel tool calling
# Processing: How to: access the RunnableConfig from a tool
# Processing: How to: stream events from a tool
# Processing: How to: return artifacts from a tool
# Processing: How to: convert Runnables to tools
# Processing: How to: add ad-hoc tool calling capability to models
# Processing: How to: pass in runtime secrets
# Processing: How to: pass multimodal data directly to models
# Processing: How to: use multimodal prompts
# Processing: How to: use legacy LangChain Agents (AgentExecutor)
# Processing: How to: migrate from legacy LangChain agents to LangGraph
# Processing: How to: pass in callbacks at runtime
# Processing: How to: attach callbacks to a module
# Processing: How to: pass callbacks into a module constructor
# Processing: How to: create custom callback handlers
# Processing: How to: use callbacks in async environments
# Processing: How to: dispatch custom callback events
# Processing: How to: create a custom chat model class
# Processing: How to: create a custom LLM class
# Processing: How to: create a custom embeddings class
# Processing: How to: write a custom retriever class
# Processing: How to: write a custom document loader
# Processing: How to: write a custom output parser class
# Processing: How to: create custom callback handlers
# Processing: How to: define a custom tool
# Processing: How to: dispatch custom callback events
# Processing: How to: save and load LangChain objects
# Processing: How to: add chat history
# Processing: How to: stream
# Processing: How to: return sources
# Processing: How to: return citations
# Processing: How to: do per-user retrieval
# Processing: How to: use reference examples
# Processing: How to: handle long text
# Processing: How to: do extraction without using function calling
# Processing: How to: manage memory
# Processing: How to: do retrieval
# Processing: How to: use tools
# Processing: How to: manage large chat history
# Processing: How to: add examples to the prompt
# Processing: How to: handle cases where no queries are generated
# Processing: How to: handle multiple queries
# Processing: How to: handle multiple retrievers
# Processing: How to: construct filters
# Processing: How to: deal with high cardinality categorical variables
# Processing: How to: use prompting to improve results
# Processing: How to: do query validation
# Processing: How to: deal with large databases
# Processing: How to: deal with CSV files
# Processing: How to: add a semantic layer over the database
# Processing: How to: construct knowledge graphs
# Processing: How to: summarize text in a single LLM call
# Processing: How to: summarize text through parallelization
# Processing: How to: summarize text through iterative refinement
# Processing: How to: chain runnables
# Processing: How to: stream runnables
# Processing: How to: invoke runnables in parallel
# Processing: How to: add default invocation args to runnables
# Processing: How to: turn any function into a runnable
# Processing: How to: pass through inputs from one chain step to the next
# Processing: How to: configure runnable behavior at runtime
# Processing: How to: add message history (memory) to a chain
# Processing: How to: route between sub-chains
# Processing: How to: create a dynamic (self-constructing) chain
# Processing: How to: inspect runnables
# Processing: How to: add fallbacks to a runnable
# Processing: How to: pass runtime secrets to a runnable
# Processing: How to: trace with LangChain
# Processing: How to: add metadata and tags to traces
